# %%
import pandas as pd

# %%
# Vytvoření prázdného DataFrame
prazdny_df= pd.DataFrame()
dataframe_se_sloupecky = pd.DataFrame (columns=["sloupec1","sloupec2","sloupec3"])
dataframe_se_sloupecky
# Out:
# Empty DataFrame
# Columns: [sloupec1, sloupec2, sloupec3]
# Index: []

# %%
# Načítání dat
novy_dataframe = pd.read_csv("branded_food.csv")
novy_dataframe
novy_dataframe.head(3)
# Další parametry při načítání CSV
# novy_dataframe = pd.read_csv("branded_food.csv", sep=";") PRO SOUBORY ODDĚLENÉ STŘEDNÍKEM
# Out:
#     fdc_id                brand_owner brand_name subbrand_name  \
# 0  1106032    BRAKEBUSH BROTHERS INC.        NaN           NaN
# 1  1107191                  Mahco Inc        NaN           NaN
# 2  1107295  Hormel Foods Corporation         NaN           NaN
#
#          gtin_upc                                        ingredients  \
# 0  10038034720202  INGREDIENTS: BONELESS CHICKEN BREAST MEAT WITH...
# 1    877448001674  TOMATO PUREE (TOMATOES), CARROTS, ONIONS, SUN-...
# 2     37600665605  MASA FLOUR (GROUND WHITE CORN WITH A TRACE OF ...
#
#   not_a_significant_source_of  serving_size serving_size_unit  \
# 0                         NaN          85.0                 g
# 1                         NaN         125.0                 g
# 2                         NaN          30.0                 g
#
#   household_serving_fulltext                           branded_food_category  \
# 0                        NaN  Meat/Poultry/Other Animals  Prepared/Processed
# 1                        NaN                   Prepared Pasta & Pizza Sauces
# 2                        NaN                        Chips, Pretzels & Snacks
#
#   data_source package_weight modified_date available_date market_country  \
# 0        GDSN            NaN    2020-09-03     2020-11-13  United States
# 1          LI            NaN    2020-09-22     2020-11-13  United States
# 2          LI            NaN    2020-04-08     2020-11-13  United States
#
#    discontinued_date preparation_state_code trade_channel short_description
# 0                NaN                    NaN           NaN               NaN
# 1                NaN                    NaN           NaN               NaN
# 2                NaN                    NaN           NaN               NaN

# %%
# Indexy
muj_dataframe.set_index("sloupecek", inplace=True) # nastaví nový index
muj_dataframe.reset_index(inplace=True) # resetuje index zpět na implicitní
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Indexy
# ----> 2 muj_dataframe.set_index("sloupecek", inplace=True) # nastaví nový index
#       3 muj_dataframe.reset_index(inplace=True) # resetuje index zpět na implicitní
#
# NameError: name 'muj_dataframe' is not defined

# %%
# Základní informace o tabulce
muj_dataframe.info() # základní informace o DataFrame (sloupce, typy, chybějící data)
muj_dataframe.shape # (počet řádků, počet sloupců)
muj_dataframe.columns # názvy všech sloupců
muj_dataframe.describe(include="all") # souhrnné statistiky včetně kategorií

muj_dataframe.head(10) # prvních 10 řádků
muj_dataframe.tail(3) # poslední 3 řádky
muj_dataframe.sample(5) # 5 náhodných řádků

# %%
# Výběr sloupců
muj_dataframe["Nazev sloupce"] # vrací Series (jednosloupcová struktura)
muj_dataframe[["Nazev sloupce", "Dalsi nazev sloupce"]] # vrací DataFrame (vícesloupcová struktura)

# %%
# Výběr řádků pomocí indexu
muj_dataframe.iloc[1:10]    # řádky 1 až 9 (0-based indexování)
muj_dataframe.iloc[:3]      # první tři řádky
muj_dataframe.iloc[-3:]     # poslední tři řádky
muj_dataframe.iloc[8:]      # od osmé řádky dále

# %%
# Výběr řádků i sloupců
muj_dataframe.iloc[:, [0, 3]] # všechny řádky a pouze sloupce 0 a 3
muj_dataframe.loc[1:4, ["Nazev Sloupce"]] # vybraný rozsah řádků a sloupce podle názvu
